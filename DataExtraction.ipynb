# %%
import pandas as pd

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.set_index(keys="Film",inplace=True)

# %%
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.reset_index(inplace=True)

# %%
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.set_index('Film',inplace=True)

# %%
bond.reset_index(inplace=True)

# %%
bond.head()
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
# 1965            Thunderball  Sean Connery  Terence Young       848.1    41.9
# 1967          Casino Royale   David Niven     Ken Hughes       315.0    85.0
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2
# 1965                4.7
# 1967                NaN

# %%
bond = pd.read_csv("jamesbond.csv",index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc["Goldfinger"]
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
bond.loc['Casino Royale']
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
bond.loc['Diamonds Are Forever':'From Russia with Love']
# Out:
#                        Year           Actor       Director  Box Office  \
# Film
# Diamonds Are Forever   1971    Sean Connery   Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan   Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery  Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore      John Glen       449.4
# From Russia with Love  1963    Sean Connery  Terence Young       543.8
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6

# %%
bond.loc[['Die Another Day','Octopussy']]
# Out:
#                  Year           Actor      Director  Box Office  Budget  \
# Film
# Die Another Day  2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
# Octopussy        1983     Roger Moore     John Glen       373.8    53.9
#
#                  Bond Actor Salary
# Film
# Die Another Day               17.9
# Octopussy                      7.8

# %%
bond = pd.read_csv("jamesbond.csv")
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.iloc[0]
bond.iloc[1:7]
bond.iloc[[9,5]]
# Out:
#                           Film  Year         Actor       Director  Box Office  \
# 9  The Man with the Golden Gun  1974   Roger Moore   Guy Hamilton       334.0
# 5          You Only Live Twice  1967  Sean Connery  Lewis Gilbert       514.2
#
#    Budget  Bond Actor Salary
# 9    27.7                NaN
# 5    59.9                4.4

# %%
bond.set_index("Film",inplace=True)
bond.sort_index(inplace=True)

# %%
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.iloc[8]
# Out:
# Year                            1995
# Actor                 Pierce Brosnan
# Director             Martin Campbell
# Box Office                     518.5
# Budget                          76.9
# Bond Actor Salary                5.1
# Name: GoldenEye, dtype: object

# %%
bond = pd.read_csv("jamesbond.csv",index_col='Film')
bond.head()
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# Casino Royale          1967   David Niven     Ken Hughes       315.0    85.0
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# Casino Royale                        NaN

# %%
bond.loc['Goldfinger','Actor']
# Out:
# 'Sean Connery'

# %%
# Out:
#   File "<ipython-input-5-bfb1b53afe9a>", line 1
#     bond.loc['Goldfinger',['Actor','Director']
#                                               ^
# SyntaxError: unexpected EOF while parsing

# %%
bond.loc['Goldfinger',['Actor','Director']]
# Out:
# Actor       Sean Connery
# Director    Guy Hamilton
# Name: Goldfinger, dtype: object

# %%
bond.iloc[0:6,1:5]
# Out:
#                               Actor       Director  Box Office  Budget
# Film
# Dr. No                 Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            Sean Connery  Terence Young       848.1    41.9
# Casino Royale           David Niven     Ken Hughes       315.0    85.0
# You Only Live Twice    Sean Connery  Lewis Gilbert       514.2    59.9

# %%
bond = pd.read_csv("jamesbond.csv",index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc['A View to a Kill','Actor'] = 'Brad Pitt'

# %%
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985       Brad Pitt        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond = pd.read_csv("jamesbond.csv",index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc['Casino Royale',"Director"]=['dasd','dsada']

# %%
bond.head()
# Out:
#                       Year           Actor      Director  Box Office  Budget  \
# Film
# A View to a Kill      1985     Roger Moore     John Glen       275.2    54.5
# Casino Royale         2006    Daniel Craig          dasd       581.5   145.3
# Casino Royale         1967     David Niven         dsada       315.0    85.0
# Diamonds Are Forever  1971    Sean Connery  Guy Hamilton       442.5    34.7
# Die Another Day       2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
#
#                       Bond Actor Salary
# Film
# A View to a Kill                    9.1
# Casino Royale                       3.3
# Casino Royale                       NaN
# Diamonds Are Forever                5.8
# Die Another Day                    17.9

# %%
bond = pd.read_csv("jamesbond.csv",index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
sean = bond['Actor'] == 'Sean Connery'

# %%
bond.loc[sean,'Actor'] =  "Sir Sean Connery"

# %%
bond
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sean Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sean Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sean Connery       Terence Young
# GoldenEye                        1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# ...

# %%
bond = pd.read_csv("jamesbond.csv",index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.rename(mapper={'Diamonds Are Forever':'Hello there',
                   'Die Another Day':'Die Today'})
bond.rename(index={'Diamonds Are Forever':'Hello there',
                   'Die Another Day':'Die Today'},inplace=True)

# %%
bond.head()
# Out:
#                   Year           Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985     Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006    Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967     David Niven       Ken Hughes       315.0    85.0
# Hello there       1971    Sean Connery     Guy Hamilton       442.5    34.7
# Die Today         2002  Pierce Brosnan     Lee Tamahori       465.4   154.2
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN
# Hello there                     5.8
# Die Today                      17.9

# %%
bond.rename({'Year':'Release Year','Director':'Producer'},axis=1)
bond.rename(columns ={'Year':'Release Year','Director':'Producer'},inplace=True)

# %%
bond.head()
# Out:
#                   Release Year           Actor         Producer  Box Office  \
# Film
# A View to a Kill          1985     Roger Moore        John Glen       275.2
# Casino Royale             2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale             1967     David Niven       Ken Hughes       315.0
# Hello there               1971    Sean Connery     Guy Hamilton       442.5
# Die Today                 2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                   Budget  Bond Actor Salary
# Film
# A View to a Kill    54.5                9.1
# Casino Royale      145.3                3.3
# Casino Royale       85.0                NaN
# Hello there         34.7                5.8
# Die Today          154.2               17.9

# %%
bond = pd.read_csv("jamesbond.csv",index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.drop('A View to a Kill')
bond.drop(['A View to a Kill','Dr. No'])
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# ...

# %%
actor = bond.pop('Actor')

# %%
bond
# Out:
#                                  Year            Director  Box Office  Budget  \
# Film
# A View to a Kill                 1985           John Glen       275.2    54.5
# Casino Royale                    2006     Martin Campbell       581.5   145.3
# Casino Royale                    1967          Ken Hughes       315.0    85.0
# Diamonds Are Forever             1971        Guy Hamilton       442.5    34.7
# Die Another Day                  2002        Lee Tamahori       465.4   154.2
# Dr. No                           1962       Terence Young       448.8     7.0
# For Your Eyes Only               1981           John Glen       449.4    60.2
# From Russia with Love            1963       Terence Young       543.8    12.6
# GoldenEye                        1995     Martin Campbell       518.5    76.9
# Goldfinger                       1964        Guy Hamilton       820.4    18.6
# Licence to Kill                  1989           John Glen       250.9    56.7
# ...

# %%
actor
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Casino Royale                         David Niven
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia with Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# Spectre                              Daniel Craig
# ...

# %%
bond = pd.read_csv("jamesbond.csv",index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.sample(5)
# Out:
#                      Year           Actor            Director  Box Office  \
# Film
# Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode       463.2
# GoldenEye            1995  Pierce Brosnan     Martin Campbell       518.5
# You Only Live Twice  1967    Sean Connery       Lewis Gilbert       514.2
# Quantum of Solace    2008    Daniel Craig        Marc Forster       514.2
# Octopussy            1983     Roger Moore           John Glen       373.8
#
#                      Budget  Bond Actor Salary
# Film
# Tomorrow Never Dies   133.9               10.0
# GoldenEye              76.9                5.1
# You Only Live Twice    59.9                4.4
# Quantum of Solace     181.4                8.1
# Octopussy              53.9                7.8

# %%
bond.sample(3,axis=1)
# Out:
#                                  Year  Budget  Box Office
# Film
# A View to a Kill                 1985    54.5       275.2
# Casino Royale                    2006   145.3       581.5
# Casino Royale                    1967    85.0       315.0
# Diamonds Are Forever             1971    34.7       442.5
# Die Another Day                  2002   154.2       465.4
# Dr. No                           1962     7.0       448.8
# For Your Eyes Only               1981    60.2       449.4
# From Russia with Love            1963    12.6       543.8
# GoldenEye                        1995    76.9       518.5
# Goldfinger                       1964    18.6       820.4
# Licence to Kill                  1989    56.7       250.9
# Live and Let Die                 1973    30.8       460.3
# Moonraker                        1979    91.5       535.0
# Never Say Never Again            1983    86.0       380.0
# Octopussy                        1983    53.9       373.8
# ...

# %%
bond = pd.read_csv("jamesbond.csv",index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.sort_values('Box Office',ascending=False).head(4)
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Spectre      2015  Daniel Craig     Sam Mendes       726.7   206.3
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2
# Spectre                    NaN

# %%
bond.nsmallest(4,'Box Office')
bond.nlargest(4,'Box Office')
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Spectre      2015  Daniel Craig     Sam Mendes       726.7   206.3
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2
# Spectre                    NaN

# %%
bond = pd.read_csv("jamesbond.csv",index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
mask = bond['Actor'] == 'Daniel Craig'

# %%
bond[mask]
# Out:
#                    Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale      2006  Daniel Craig  Martin Campbell       581.5   145.3
# Quantum of Solace  2008  Daniel Craig     Marc Forster       514.2   181.4
# Skyfall            2012  Daniel Craig       Sam Mendes       943.5   170.2
# Spectre            2015  Daniel Craig       Sam Mendes       726.7   206.3
#
#                    Bond Actor Salary
# Film
# Casino Royale                    3.3
# Quantum of Solace                8.1
# Skyfall                         14.5
# Spectre                          NaN

# %%
bond.where(mask)
# Out:
#                                    Year         Actor         Director  \
# Film
# A View to a Kill                    NaN           NaN              NaN
# Casino Royale                    2006.0  Daniel Craig  Martin Campbell
# Casino Royale                       NaN           NaN              NaN
# Diamonds Are Forever                NaN           NaN              NaN
# Die Another Day                     NaN           NaN              NaN
# Dr. No                              NaN           NaN              NaN
# For Your Eyes Only                  NaN           NaN              NaN
# From Russia with Love               NaN           NaN              NaN
# GoldenEye                           NaN           NaN              NaN
# Goldfinger                          NaN           NaN              NaN
# Licence to Kill                     NaN           NaN              NaN
# Live and Let Die                    NaN           NaN              NaN
# ...

# %%
bond = pd.read_csv("jamesbond.csv",index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.rename({'Box Office':'Box_Office','Bond Actor Salary':'Bond_Actor_Salary'},axis=1,inplace=True)

# %%
bond.query('Actor == "Sean Connery"')
# Out:
#                        Year         Actor        Director  Box_Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond_Actor_Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond.query('Actor == "Sean Connery" and Box_Office > 500')
# Out:
#                        Year         Actor       Director  Box_Office  Budget  \
# Film
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery  Lewis Gilbert       514.2    59.9
#
#                        Bond_Actor_Salary
# Film
# From Russia with Love                1.6
# Goldfinger                           3.2
# Thunderball                          4.7
# You Only Live Twice                  4.4

# %%
bond.query("Actor in ['Daniel Craig','Sean Connery']")
# Out:
#                        Year         Actor         Director  Box_Office  \
# Film
# Casino Royale          2006  Daniel Craig  Martin Campbell       581.5
# Diamonds Are Forever   1971  Sean Connery     Guy Hamilton       442.5
# Dr. No                 1962  Sean Connery    Terence Young       448.8
# From Russia with Love  1963  Sean Connery    Terence Young       543.8
# Goldfinger             1964  Sean Connery     Guy Hamilton       820.4
# Never Say Never Again  1983  Sean Connery   Irvin Kershner       380.0
# Quantum of Solace      2008  Daniel Craig     Marc Forster       514.2
# Skyfall                2012  Daniel Craig       Sam Mendes       943.5
# Spectre                2015  Daniel Craig       Sam Mendes       726.7
# Thunderball            1965  Sean Connery    Terence Young       848.1
# You Only Live Twice    1967  Sean Connery    Lewis Gilbert       514.2
#
#                        Budget  Bond_Actor_Salary
# Film
# Casino Royale           145.3                3.3
# ...

# %%
bond.query("Actor not in ['Daniel Craig','Sean Connery']")
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    1967     David Niven          Ken Hughes
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# For Your Eyes Only               1981     Roger Moore           John Glen
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Octopussy                        1983     Roger Moore           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# The Living Daylights             1987  Timothy Dalton           John Glen
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# ...

# %%
bond = pd.read_csv("jamesbond.csv",index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
def func(number):
    return str(number) + "MILLIONs"
bond['Box Office'].apply(func)
# Out:
# Film
# A View to a Kill                   275.2MILLIONs
# Casino Royale                      581.5MILLIONs
# Casino Royale                      315.0MILLIONs
# Diamonds Are Forever               442.5MILLIONs
# Die Another Day                    465.4MILLIONs
# Dr. No                             448.8MILLIONs
# For Your Eyes Only                 449.4MILLIONs
# From Russia with Love              543.8MILLIONs
# GoldenEye                          518.5MILLIONs
# Goldfinger                         820.4MILLIONs
# Licence to Kill                    250.9MILLIONs
# Live and Let Die                   460.3MILLIONs
# Moonraker                          535.0MILLIONs
# Never Say Never Again              380.0MILLIONs
# Octopussy                          373.8MILLIONs
# On Her Majesty's Secret Service    291.5MILLIONs
# Quantum of Solace                  514.2MILLIONs
# Skyfall                            943.5MILLIONs
# Spectre                            726.7MILLIONs
# ...

# %%
bond = pd.read_csv("jamesbond.csv",index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
def review_movies(row):
    boxoffice=row[3]
    budget=row[4]
    if boxoffice>400 and budget<80:
        return "good movie"
    else:
        return "bad movie"
 
bond.apply(review_movies,axis=1)
# Out:
# Film
# A View to a Kill                    bad movie
# Casino Royale                       bad movie
# Casino Royale                       bad movie
# Diamonds Are Forever               good movie
# Die Another Day                     bad movie
# Dr. No                             good movie
# For Your Eyes Only                 good movie
# From Russia with Love              good movie
# GoldenEye                          good movie
# Goldfinger                         good movie
# Licence to Kill                     bad movie
# Live and Let Die                   good movie
# Moonraker                           bad movie
# Never Say Never Again               bad movie
# Octopussy                           bad movie
# On Her Majesty's Secret Service     bad movie
# Quantum of Solace                   bad movie
# Skyfall                             bad movie
# Spectre                             bad movie
# The Living Daylights                bad movie
# ...

# %%
bond = pd.read_csv("jamesbond.csv",index_col='Film')
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
Directors = bond['Director'].copy()

# %%
Directors['Dr. No']= "Daniel Craig"
Directors.head(8)
# Out:
# Film
# A View to a Kill               John Glen
# Casino Royale            Martin Campbell
# Casino Royale                 Ken Hughes
# Diamonds Are Forever        Guy Hamilton
# Die Another Day             Lee Tamahori
# Dr. No                      Daniel Craig
# For Your Eyes Only             John Glen
# From Russia with Love      Terence Young
# Name: Director, dtype: object

# %%
bond.head(8)
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# A View to a Kill       1985     Roger Moore        John Glen       275.2
# Casino Royale          2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale          1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever   1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
#
#                        Budget  Bond Actor Salary
# Film
# A View to a Kill         54.5                9.1
# Casino Royale           145.3                3.3
# Casino Royale            85.0                NaN
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# ...
